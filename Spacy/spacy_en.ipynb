# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
en_text = "Perhaps one of the most significant advances made byArabic mathematicsbegan at this time with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowedrational numbers,irrational numbers, geometrical magnitudes, etc., to all be treated as 'algebraic objects'. It gave mathematics a whole new development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itselfin a way which had not happened before."

# %%
document_en = nlp(en_text)

# %% [markdown]
# # Tokenization

# %%
tokens = [token.text for token in document_en]
tokens
# Out:
# ['Perhaps',
#  'one',
#  'of',
#  'the',
#  'most',
#  'significant',
#  'advances',
#  'made',
#  'byArabic',
#  'mathematicsbegan',
#  'at',
#  'this',
#  'time',
#  'with',
#  'the',
#  'work',
#  'of',
#  'al',
#  '-',
#  'Khwarizmi',
#  ',',
#  'namely',
#  'the',
#  'beginnings',
#  'of',
#  'algebra',
#  '.',
#  'It',
#  'is',
#  'important',
#  'to',
#  'understand',
#  'just',
#  'how',
#  'significant',
#  'this',
#  'new',
#  'idea',
#  'was',
#  '.',
#  'It',
#  'was',
#  'a',
#  'revolutionary',
#  'move',
#  'away',
#  'from',
#  'the',
#  'Greek',
#  'concept',
#  'of',
#  'mathematics',
#  'which',
#  'was',
#  'essentially',
#  'geometry',
#  '.',
#  'Algebra',
#  'was',
#  'a',
#  'unifying',
#  'theory',
#  'which',
#  'allowedrational',
#  'numbers',
#  ',',
#  'irrational',
#  'numbers',
#  ',',
#  'geometrical',
#  'magnitudes',
#  ',',
#  'etc',
#  '.',
#  ',',
#  'to',
#  'all',
#  'be',
#  'treated',
#  'as',
#  "'",
#  'algebraic',
#  'objects',
#  "'",
#  '.',
#  'It',
#  'gave',
#  'mathematics',
#  'a',
#  'whole',
#  'new',
#  'development',
#  'path',
#  'so',
#  'much',
#  'broader',
#  'in',
#  'concept',
#  'to',
#  'that',
#  'which',
#  'had',
#  'existed',
#  'before',
#  ',',
#  'and',
#  'provided',
#  'a',
#  'vehicle',
#  'for',
#  'future',
#  'development',
#  'of',
#  'the',
#  'subject',
#  '.',
#  'Another',
#  'important',
#  'aspect',
#  'of',
#  'the',
#  'introduction',
#  'of',
#  'algebraic',
#  'ideas',
#  'was',
#  'that',
#  'it',
#  'allowed',
#  'mathematics',
#  'to',
#  'be',
#  'applied',
#  'to',
#  'itselfin',
#  'a',
#  'way',
#  'which',
#  'had',
#  'not',
#  'happened',
#  'before',
#  '.']

# %% [markdown]
# # Lemmatization

# %%
for token in document_en:
    print(f"{token.pos_} || {token.text} ===> {token.lemma_}")
# Out:
# ADV || Perhaps ===> perhaps
# NUM || one ===> one
# ADP || of ===> of
# DET || the ===> the
# ADV || most ===> most
# ADJ || significant ===> significant
# NOUN || advances ===> advance
# VERB || made ===> make
# ADJ || byArabic ===> byarabic
# NOUN || mathematicsbegan ===> mathematicsbegan
# ADP || at ===> at
# DET || this ===> this
# NOUN || time ===> time
# ADP || with ===> with
# DET || the ===> the
# NOUN || work ===> work
# ADP || of ===> of
# PROPN || al ===> al
# PUNCT || - ===> -
# PROPN || Khwarizmi ===> Khwarizmi
# PUNCT || , ===> ,
# ADV || namely ===> namely
# DET || the ===> the
# NOUN || beginnings ===> beginning
# ADP || of ===> of
# PROPN || algebra ===> algebra
# PUNCT || . ===> .
# PRON || It ===> it
# AUX || is ===> be
# ADJ || important ===> important
# PART || to ===> to
# VERB || understand ===> understand
# ADV || just ===> just
# ADV || how ===> how
# ADJ || significant ===> significant
# DET || this ===> this
# ADJ || new ===> new
# NOUN || idea ===> idea
# AUX || was ===> be
# PUNCT || . ===> .
# PRON || It ===> it
# AUX || was ===> be
# DET || a ===> a
# ADJ || revolutionary ===> revolutionary
# NOUN || move ===> move
# ADV || away ===> away
# ADP || from ===> from
# DET || the ===> the
# ADJ || Greek ===> greek
# NOUN || concept ===> concept
# ADP || of ===> of
# NOUN || mathematics ===> mathematic
# DET || which ===> which
# VERB || was ===> be
# ADV || essentially ===> essentially
# NOUN || geometry ===> geometry
# PUNCT || . ===> .
# PROPN || Algebra ===> Algebra
# AUX || was ===> be
# DET || a ===> a
# ADJ || unifying ===> unifying
# NOUN || theory ===> theory
# DET || which ===> which
# ADJ || allowedrational ===> allowedrational
# NOUN || numbers ===> number
# PUNCT || , ===> ,
# ADJ || irrational ===> irrational
# NOUN || numbers ===> number
# PUNCT || , ===> ,
# ADJ || geometrical ===> geometrical
# NOUN || magnitudes ===> magnitude
# PUNCT || , ===> ,
# X || etc ===> etc
# X || . ===> .
# PUNCT || , ===> ,
# ADP || to ===> to
# DET || all ===> all
# AUX || be ===> be
# VERB || treated ===> treat
# ADP || as ===> as
# PUNCT || ' ===> '
# ADJ || algebraic ===> algebraic
# NOUN || objects ===> object
# PUNCT || ' ===> '
# PUNCT || . ===> .
# PRON || It ===> it
# VERB || gave ===> give
# NOUN || mathematics ===> mathematic
# DET || a ===> a
# ADJ || whole ===> whole
# ADJ || new ===> new
# NOUN || development ===> development
# NOUN || path ===> path
# ADV || so ===> so
# ADV || much ===> much
# ADJ || broader ===> broad
# ADP || in ===> in
# NOUN || concept ===> concept
# ADP || to ===> to
# DET || that ===> that
# DET || which ===> which
# AUX || had ===> have
# VERB || existed ===> exist
# ADV || before ===> before
# PUNCT || , ===> ,
# CCONJ || and ===> and
# VERB || provided ===> provide
# DET || a ===> a
# NOUN || vehicle ===> vehicle
# ADP || for ===> for
# ADJ || future ===> future
# NOUN || development ===> development
# ADP || of ===> of
# DET || the ===> the
# NOUN || subject ===> subject
# PUNCT || . ===> .
# DET || Another ===> another
# ADJ || important ===> important
# NOUN || aspect ===> aspect
# ADP || of ===> of
# DET || the ===> the
# NOUN || introduction ===> introduction
# ADP || of ===> of
# ADJ || algebraic ===> algebraic
# NOUN || ideas ===> idea
# AUX || was ===> be
# SCONJ || that ===> that
# PRON || it ===> it
# VERB || allowed ===> allow
# NOUN || mathematics ===> mathematic
# PART || to ===> to
# AUX || be ===> be
# VERB || applied ===> apply
# PART || to ===> to
# VERB || itselfin ===> itselfin
# DET || a ===> a
# NOUN || way ===> way
# DET || which ===> which
# AUX || had ===> have
# PART || not ===> not
# VERB || happened ===> happen
# ADV || before ===> before
# PUNCT || . ===> .

# %% [markdown]
# # Part of speech tagging

# %%
for token in document_en:
    print(f"{token.tag_} || {token.pos_} || {token.text}")
# Out:
# RB || ADV || Perhaps
# CD || NUM || one
# IN || ADP || of
# DT || DET || the
# RBS || ADV || most
# JJ || ADJ || significant
# NNS || NOUN || advances
# VBD || VERB || made
# JJ || ADJ || byArabic
# NN || NOUN || mathematicsbegan
# IN || ADP || at
# DT || DET || this
# NN || NOUN || time
# IN || ADP || with
# DT || DET || the
# NN || NOUN || work
# IN || ADP || of
# NNP || PROPN || al
# HYPH || PUNCT || -
# NNP || PROPN || Khwarizmi
# , || PUNCT || ,
# RB || ADV || namely
# DT || DET || the
# NNS || NOUN || beginnings
# IN || ADP || of
# NNP || PROPN || algebra
# . || PUNCT || .
# PRP || PRON || It
# VBZ || AUX || is
# JJ || ADJ || important
# TO || PART || to
# VB || VERB || understand
# RB || ADV || just
# WRB || ADV || how
# JJ || ADJ || significant
# DT || DET || this
# JJ || ADJ || new
# NN || NOUN || idea
# VBD || AUX || was
# . || PUNCT || .
# PRP || PRON || It
# VBD || AUX || was
# DT || DET || a
# JJ || ADJ || revolutionary
# NN || NOUN || move
# RB || ADV || away
# IN || ADP || from
# DT || DET || the
# JJ || ADJ || Greek
# NN || NOUN || concept
# IN || ADP || of
# NNS || NOUN || mathematics
# WDT || DET || which
# VBD || VERB || was
# RB || ADV || essentially
# NN || NOUN || geometry
# . || PUNCT || .
# NNP || PROPN || Algebra
# VBD || AUX || was
# DT || DET || a
# JJ || ADJ || unifying
# NN || NOUN || theory
# WDT || DET || which
# JJ || ADJ || allowedrational
# NNS || NOUN || numbers
# , || PUNCT || ,
# JJ || ADJ || irrational
# NNS || NOUN || numbers
# , || PUNCT || ,
# JJ || ADJ || geometrical
# NNS || NOUN || magnitudes
# , || PUNCT || ,
# FW || X || etc
# FW || X || .
# , || PUNCT || ,
# IN || ADP || to
# DT || DET || all
# VB || AUX || be
# VBN || VERB || treated
# IN || ADP || as
# `` || PUNCT || '
# JJ || ADJ || algebraic
# NNS || NOUN || objects
# '' || PUNCT || '
# . || PUNCT || .
# PRP || PRON || It
# VBD || VERB || gave
# NNS || NOUN || mathematics
# DT || DET || a
# JJ || ADJ || whole
# JJ || ADJ || new
# NN || NOUN || development
# NN || NOUN || path
# RB || ADV || so
# RB || ADV || much
# JJR || ADJ || broader
# IN || ADP || in
# NN || NOUN || concept
# IN || ADP || to
# DT || DET || that
# WDT || DET || which
# VBD || AUX || had
# VBN || VERB || existed
# RB || ADV || before
# , || PUNCT || ,
# CC || CCONJ || and
# VBD || VERB || provided
# DT || DET || a
# NN || NOUN || vehicle
# IN || ADP || for
# JJ || ADJ || future
# NN || NOUN || development
# IN || ADP || of
# DT || DET || the
# NN || NOUN || subject
# . || PUNCT || .
# DT || DET || Another
# JJ || ADJ || important
# NN || NOUN || aspect
# IN || ADP || of
# DT || DET || the
# NN || NOUN || introduction
# IN || ADP || of
# JJ || ADJ || algebraic
# NNS || NOUN || ideas
# VBD || AUX || was
# IN || SCONJ || that
# PRP || PRON || it
# VBD || VERB || allowed
# NNS || NOUN || mathematics
# TO || PART || to
# VB || AUX || be
# VBN || VERB || applied
# TO || PART || to
# VB || VERB || itselfin
# DT || DET || a
# NN || NOUN || way
# WDT || DET || which
# VBD || AUX || had
# RB || PART || not
# VBN || VERB || happened
# RB || ADV || before
# . || PUNCT || .

# %% [markdown]
# # Chunking

# %%
for chunk in document_en.noun_chunks:
    print(chunk.label_, chunk)
# Out:
# NP the most significant advances
# NP byArabic mathematicsbegan
# NP this time
# NP the work
# NP al-Khwarizmi
# NP namely the beginnings
# NP algebra
# NP It
# NP this new idea
# NP It
# NP a revolutionary move
# NP the Greek concept
# NP mathematics
# NP essentially geometry
# NP Algebra
# NP a unifying theory
# NP allowedrational numbers
# NP irrational numbers
# NP geometrical magnitudes
# NP 'algebraic objects
# NP It
# NP mathematics
# NP a whole new development path
# NP concept
# NP a vehicle
# NP future development
# NP the subject
# NP Another important aspect
# NP the introduction
# NP algebraic ideas
# NP it
# NP mathematics
# NP a way

# %% [markdown]
# # Get dependencies

# %%
# %load_ext watermark

# %%
# %watermark -p spacy
# Out:
# spacy: 3.1.0
