# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string
import nltk

# %%
ar_text = u"ولعل أحد أهم التطورات التي حققتها الرياضيات العربية بدأ في هذا الوقت مع عمل الخوارزمي ، أي بدايات الجبر. من المهم أن نفهم مدى أهمية هذه الفكرة الجديدة. لقد كان ابتعادًا ثوريًا عن المفهوم اليوناني للرياضيات الذي كان أساسًا الهندسة. كان الجبر نظرية موحدة سمحت بأن يتم التعامل مع الأعداد العقلانية والأعداد غير المنطقية والمقادير الهندسية وما إلى ذلك على أنها 'كائنات جبرية'. لقد أعطى الرياضيات مسارًا جديدًا تمامًا للتطور أوسع بكثير من حيث المفهوم إلى ما كان موجودًا من قبل ، ووفر وسيلة للتطور المستقبلي للموضوع. جانب آخر مهم لإدخال الأفكار الجبرية هو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل"

# %% [markdown]
# # Clear text from ponctuations

# %%
clearedText = ar_text.translate(str.maketrans("", "", string.punctuation))
clearedText

# %% [markdown]
# # Tokenization

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
stopwords = stopwords.words("arabic")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Imad
# [nltk_data]     AKEL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
words_tokens = word_tokenize(clearedText)
filtered_list = []
for word in words_tokens:
    if word not in stopwords:
        filtered_list.append(word)
        
filtered_list
# Out:
# ['ولعل',
#  'أحد',
#  'أهم',
#  'التطورات',
#  'حققتها',
#  'الرياضيات',
#  'العربية',
#  'بدأ',
#  'الوقت',
#  'عمل',
#  'الخوارزمي',
#  '،',
#  'بدايات',
#  'الجبر',
#  'المهم',
#  'نفهم',
#  'مدى',
#  'أهمية',
#  'الفكرة',
#  'الجديدة',
#  'لقد',
#  'كان',
#  'ابتعادًا',
#  'ثوريًا',
#  'المفهوم',
#  'اليوناني',
#  'للرياضيات',
#  'كان',
#  'أساسًا',
#  'الهندسة',
#  'كان',
#  'الجبر',
#  'نظرية',
#  'موحدة',
#  'سمحت',
#  'بأن',
#  'يتم',
#  'التعامل',
#  'الأعداد',
#  'العقلانية',
#  'والأعداد',
#  'المنطقية',
#  'والمقادير',
#  'الهندسية',
#  'أنها',
#  'كائنات',
#  'جبرية',
#  'لقد',
#  'أعطى',
#  'الرياضيات',
#  'مسارًا',
#  'جديدًا',
#  'تمامًا',
#  'للتطور',
#  'أوسع',
#  'بكثير',
#  'المفهوم',
#  'كان',
#  'موجودًا',
#  'قبل',
#  '،',
#  'ووفر',
#  'وسيلة',
#  'للتطور',
#  'المستقبلي',
#  'للموضوع',
#  'جانب',
#  'آخر',
#  'مهم',
#  'لإدخال',
#  'الأفكار',
#  'الجبرية',
#  'أنه',
#  'سمح',
#  'بتطبيق',
#  'الرياضيات',
#  'نفسها',
#  'بطريقة',
#  'تحدث',
#  'قبل']

# %% [markdown]
# # Stemming

# %%
stemmer = PorterStemmer()
stemmed_words = []
for word in filtered_list:
    stem = stemmer.stem(word)
    stemmed_words.append(stem)
    print(f"{word}  ============> {stem}")
# Out:
# ولعل  ============> ولعل
# أحد  ============> أحد
# أهم  ============> أهم
# التطورات  ============> التطورات
# حققتها  ============> حققتها
# الرياضيات  ============> الرياضيات
# العربية  ============> العربية
# بدأ  ============> بدأ
# الوقت  ============> الوقت
# عمل  ============> عمل
# الخوارزمي  ============> الخوارزمي
# ،  ============> ،
# بدايات  ============> بدايات
# الجبر  ============> الجبر
# المهم  ============> المهم
# نفهم  ============> نفهم
# مدى  ============> مدى
# أهمية  ============> أهمية
# الفكرة  ============> الفكرة
# الجديدة  ============> الجديدة
# لقد  ============> لقد
# كان  ============> كان
# ابتعادًا  ============> ابتعادًا
# ثوريًا  ============> ثوريًا
# المفهوم  ============> المفهوم
# اليوناني  ============> اليوناني
# للرياضيات  ============> للرياضيات
# كان  ============> كان
# أساسًا  ============> أساسًا
# الهندسة  ============> الهندسة
# كان  ============> كان
# الجبر  ============> الجبر
# نظرية  ============> نظرية
# موحدة  ============> موحدة
# سمحت  ============> سمحت
# بأن  ============> بأن
# يتم  ============> يتم
# التعامل  ============> التعامل
# الأعداد  ============> الأعداد
# العقلانية  ============> العقلانية
# والأعداد  ============> والأعداد
# المنطقية  ============> المنطقية
# والمقادير  ============> والمقادير
# الهندسية  ============> الهندسية
# أنها  ============> أنها
# كائنات  ============> كائنات
# جبرية  ============> جبرية
# لقد  ============> لقد
# أعطى  ============> أعطى
# الرياضيات  ============> الرياضيات
# مسارًا  ============> مسارًا
# جديدًا  ============> جديدًا
# تمامًا  ============> تمامًا
# للتطور  ============> للتطور
# أوسع  ============> أوسع
# بكثير  ============> بكثير
# المفهوم  ============> المفهوم
# كان  ============> كان
# موجودًا  ============> موجودًا
# قبل  ============> قبل
# ،  ============> ،
# ووفر  ============> ووفر
# وسيلة  ============> وسيلة
# للتطور  ============> للتطور
# المستقبلي  ============> المستقبلي
# للموضوع  ============> للموضوع
# جانب  ============> جانب
# آخر  ============> آخر
# مهم  ============> مهم
# لإدخال  ============> لإدخال
# الأفكار  ============> الأفكار
# الجبرية  ============> الجبرية
# أنه  ============> أنه
# سمح  ============> سمح
# بتطبيق  ============> بتطبيق
# الرياضيات  ============> الرياضيات
# نفسها  ============> نفسها
# بطريقة  ============> بطريقة
# تحدث  ============> تحدث
# قبل  ============> قبل

# %% [markdown]
# # Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemma_words = []
for word in filtered_list:
    lemma = lemmatizer.lemmatize(word)
    lemma_words.append(lemma)
    print(f"{word}  ============> {lemma}")
# Out:
# ولعل  ============> ولعل
# أحد  ============> أحد
# أهم  ============> أهم
# التطورات  ============> التطورات
# حققتها  ============> حققتها
# الرياضيات  ============> الرياضيات
# العربية  ============> العربية
# بدأ  ============> بدأ
# الوقت  ============> الوقت
# عمل  ============> عمل
# الخوارزمي  ============> الخوارزمي
# ،  ============> ،
# بدايات  ============> بدايات
# الجبر  ============> الجبر
# المهم  ============> المهم
# نفهم  ============> نفهم
# مدى  ============> مدى
# أهمية  ============> أهمية
# الفكرة  ============> الفكرة
# الجديدة  ============> الجديدة
# لقد  ============> لقد
# كان  ============> كان
# ابتعادًا  ============> ابتعادًا
# ثوريًا  ============> ثوريًا
# المفهوم  ============> المفهوم
# اليوناني  ============> اليوناني
# للرياضيات  ============> للرياضيات
# كان  ============> كان
# أساسًا  ============> أساسًا
# الهندسة  ============> الهندسة
# كان  ============> كان
# الجبر  ============> الجبر
# نظرية  ============> نظرية
# موحدة  ============> موحدة
# سمحت  ============> سمحت
# بأن  ============> بأن
# يتم  ============> يتم
# التعامل  ============> التعامل
# الأعداد  ============> الأعداد
# العقلانية  ============> العقلانية
# والأعداد  ============> والأعداد
# المنطقية  ============> المنطقية
# والمقادير  ============> والمقادير
# الهندسية  ============> الهندسية
# أنها  ============> أنها
# كائنات  ============> كائنات
# جبرية  ============> جبرية
# لقد  ============> لقد
# أعطى  ============> أعطى
# الرياضيات  ============> الرياضيات
# مسارًا  ============> مسارًا
# جديدًا  ============> جديدًا
# تمامًا  ============> تمامًا
# للتطور  ============> للتطور
# أوسع  ============> أوسع
# بكثير  ============> بكثير
# المفهوم  ============> المفهوم
# كان  ============> كان
# موجودًا  ============> موجودًا
# قبل  ============> قبل
# ،  ============> ،
# ووفر  ============> ووفر
# وسيلة  ============> وسيلة
# للتطور  ============> للتطور
# المستقبلي  ============> المستقبلي
# للموضوع  ============> للموضوع
# جانب  ============> جانب
# آخر  ============> آخر
# مهم  ============> مهم
# لإدخال  ============> لإدخال
# الأفكار  ============> الأفكار
# الجبرية  ============> الجبرية
# أنه  ============> أنه
# سمح  ============> سمح
# بتطبيق  ============> بتطبيق
# الرياضيات  ============> الرياضيات
# نفسها  ============> نفسها
# بطريقة  ============> بطريقة
# تحدث  ============> تحدث
# قبل  ============> قبل
